# %% [markdown]
# <a href="https://colab.research.google.com/github/otaviojts/aps/blob/main/aps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalando o yahoo finance
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 42.3 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
# !pip install requests --upgrade --no-cache-dir
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install --upgrade pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf #Instalando e importando a API no código
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
import requests
url = "https://investnews.com.br/financas/veja-a-lista-completa-dos-bdrs-disponiveis-para-pessoas-fisicas-na-b3/"
r = requests.get(url)
html = r.text
df_nomes_tickers = pd.read_html(html, header=0)[0]
df_nomes_tickers.head(10)

# %%
with pd.option_context('display.max_rows',10):
  print(df_nomes_tickers)
# Out:
#            EMPRESA  CÓDIGO                                   SETOR  \
# 0               3M  MMMC34                 Indústria diversificada
# 1         AB INBEV  ABUD34                                 Bebidas
# 2          ABB LTD  A1BB34                              Industrial
# 3           ABBOTT  ABTT34                           Farmacêuticos
# 4           ABBVIE  ABBV34          Medicamentos e Outros Produtos
# ..             ...     ...                                     ...
# 703  RAYTHEON TECH  RYTT34                              Industrial
# 704   SCHLUMBERGER  SLBG34  Equipamentos e Serviços de Combustível
# 705        TIFFANY  TIFF34                               Joalheria
# 706     US BANCORP  USBC34                  Instituição Financeira
# 707         XP INC  XPBR31                              Financeiro
#
#     PAÍS DE ORIGEM
# 0              EUA
# 1          Bélgica
# 2      Switzerland
# 3              EUA
# 4              EUA
# ..             ...
# ...

# %%
import pandas as pd
import matplotlib.pylab as plt
import yfinance as yf
import warnings
import matplotlib
import statsmodels.api as sm

# %%
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'G'

# %%
# importar pacotes necessários
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados_series = yf.download("MUTC34.SA", start="2022-04-01", end="2022-10-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
with pd.option_context('display.max_rows',10):
  print(dados_series)
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2022-04-01  376.579987  379.950012  375.000000  375.190002  372.784363     248
# 2022-04-04  373.540009  373.540009  371.019989  371.019989  368.641083     114
# 2022-04-05  374.070007  376.670013  373.040009  373.329987  370.936279     517
# 2022-04-06  376.489990  379.619995  374.890015  376.929993  374.513184     589
# 2022-04-07  380.179993  382.459991  380.000000  380.000000  377.563507      52
# ...                ...         ...         ...         ...         ...     ...
# 2022-10-24  382.519989  383.660004  380.750000  383.660004  383.660004      62
# 2022-10-25  386.079987  387.470001  384.670013  384.670013  384.670013     167
# 2022-10-26  387.480011  390.000000  385.320007  387.750000  387.750000     100
# 2022-10-27  382.970001  387.600006  373.000000  386.010010  386.010010     125
# 2022-10-28  388.579987  389.880005  386.410004  387.850006  387.850006     275
#
# ...

# %%
dados_series2 = yf.download("A1YX34.SA", start="2022-04-01", end="2022-10-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dados_series3 = yf.download("J1CI34.SA", start="2022-04-01", end="2022-10-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dados_series4 = yf.download("MMMC34.SA", start="2022-04-01", end="2022-10-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dados_series5 = yf.download("AALL34.SA", start="2022-04-01", end="2022-10-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dados_series6 = yf.download("AAPL34.SA", start="2022-04-01", end="2022-10-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dados_series7 = yf.download("CSCO34.SA", start="2022-04-01", end="2022-10-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dados_series8 = yf.download("EBAY34.SA", start="2022-04-01", end="2022-10-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dados_series9 = yf.download("K1EY34.SA", start="2022-04-01", end="2022-10-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dados_series10 = yf.download("ITLC34.SA", start="2022-04-01", end="2022-10-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series2['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series3['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series4['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series5['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series6['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series7['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series8['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series9['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series10['Close'].dropna())
